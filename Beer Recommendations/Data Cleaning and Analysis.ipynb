# %%
import requests
from bs4 import BeautifulSoup
from lxml import html
import pandas as pd
import nltk
from string import punctuation
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
stop_words = set( stopwords.words('english'))
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import spacy 
import numpy as np
import string
import vaderSentiment

# %% [markdown]
# ### Cleaning the data

# %%
reviews_df = pd.read_csv('reviews.csv')
reviews_df[:10]
# Out:
#                   product_name  \
# 0  Kentucky Brunch Brand Stout
# 1  Kentucky Brunch Brand Stout
# 2  Kentucky Brunch Brand Stout
# 3  Kentucky Brunch Brand Stout
# 4  Kentucky Brunch Brand Stout
# 5  Kentucky Brunch Brand Stout
# 6  Kentucky Brunch Brand Stout
# 7  Kentucky Brunch Brand Stout
# 8  Kentucky Brunch Brand Stout
# 9  Kentucky Brunch Brand Stout
#
#                                       product_review  user_rating
# 0  2016 Silver Wax. Aroma has whiskey, maple, tof...         4.80
# 1  The beer pours Pitch Black with a frothy tan h...         4.74
# 2  Probably the smoothest beer I have ever had. S...         4.68
# 3  Dark black, very thick, a little bit of tan he...         5.00
# 4  Poured black as ink with thin ruby edges at 58...         4.97
# 5  she’s got heat....but man is she somethin nice...         4.75
# 6  Amazing brew. The maple aroma pours out of thi...         5.00
# 7  Finally got to try the white whale. Pours like...         4.30
# 8  Had this on tap at the 12-15-18 release in Dec...         4.85
# 9  Had this on tap At the KBBS release 12/15/18 p...         4.89

# %%
#Checking if there are 25 reviews of each product
reviews_df.groupby(['product_name']).count()
# Out:
#                                                     product_review  \
# product_name
# 3rd Anniversary Imperial IPA                                    25
# 4th Anniversary                                                 22
# A Deal With The Devil                                           25
# Aaron                                                           25
# Abner                                                           25
# Abrasive Ale                                                    25
# Abraxas                                                         25
# Abricot Du Fermier                                              25
# Abt 12                                                          25
# Adam From The Wood                                              25
# All That Is And All That Ever Will Be                           25
# Alter Ego                                                       25
# Anabasis                                                        20
# Ann                                                             25
# Apple Brandy Barrel Noir                                        25
# Art                                                             25
# Assassin                                                        25
# Atrial Rubicite                                                 25
# Aurelian Lure                                                   25
# Axe Man                                                         25
# BBADL (Bourbon Barrel Aged Dark Lord Imperial S...              25
# BDCS                                                            25
# Bad Boy                                                         25
# Barrel Aged Bomb!                                               25
# Barrel Aged Imperial German Chocolate Cupcake S...              25
# Barrel-Aged Abraxas                                             25
# Barrel-Aged Silhouette                                          25
# Barrel-Aged Sump Coffee Stout                                   25
# Beatification                                                   25
# Beer Geek Vanilla Shake - Bourbon Barrel-Aged                   25
# ...                                                            ...
# Sunday Brunch                                                   25
# Supplication                                                    25
# Susan                                                           25
# Swish                                                           25
# Temptation                                                      25
# Ten FIDY - Bourbon Barrel Aged                                  25
# The Abyss                                                       25
# The Broken Truck                                                25
# The Peach                                                       25
# The Rusty Nail                                                  25
# Thicket                                                         25
# Trappist Westvleteren 12 (XII)                                  25
# Trappist Westvleteren 8 (VIII)                                  25
# Trappistes Rochefort 10                                         25
# Triple Shot                                                     25
# Triple Sunshine                                                 25
# Tweak                                                           25
# Upper Case                                                      25
# V.S.O.J.                                                        25
# Very GGGreennn                                                  23
# Very Green                                                      25
# Very Hazy                                                       25
# Vicinity                                                        25
# Weihenstephaner Hefeweissbier                                   25
# West Ashley                                                     25
# Westly                                                          25
# Wide Awake It's Morning                                         25
# Zenne Y Frontera                                                25
# Zombie Dust                                                     25
# §ucaba                                                          25
#
#                                                     user_rating
# product_name
# 3rd Anniversary Imperial IPA                                 25
# 4th Anniversary                                              22
# A Deal With The Devil                                        25
# Aaron                                                        25
# Abner                                                        25
# Abrasive Ale                                                 25
# Abraxas                                                      25
# Abricot Du Fermier                                           25
# Abt 12                                                       25
# Adam From The Wood                                           25
# All That Is And All That Ever Will Be                        25
# Alter Ego                                                    25
# Anabasis                                                     20
# Ann                                                          25
# Apple Brandy Barrel Noir                                     25
# Art                                                          25
# Assassin                                                     25
# Atrial Rubicite                                              25
# Aurelian Lure                                                25
# Axe Man                                                      25
# BBADL (Bourbon Barrel Aged Dark Lord Imperial S...           25
# BDCS                                                         25
# Bad Boy                                                      25
# Barrel Aged Bomb!                                            25
# Barrel Aged Imperial German Chocolate Cupcake S...           25
# Barrel-Aged Abraxas                                          25
# Barrel-Aged Silhouette                                       25
# Barrel-Aged Sump Coffee Stout                                25
# Beatification                                                25
# Beer Geek Vanilla Shake - Bourbon Barrel-Aged                25
# ...                                                         ...
# Sunday Brunch                                                25
# Supplication                                                 25
# Susan                                                        25
# Swish                                                        25
# Temptation                                                   25
# Ten FIDY - Bourbon Barrel Aged                               25
# The Abyss                                                    25
# The Broken Truck                                             25
# The Peach                                                    25
# The Rusty Nail                                               25
# Thicket                                                      25
# Trappist Westvleteren 12 (XII)                               25
# Trappist Westvleteren 8 (VIII)                               25
# Trappistes Rochefort 10                                      25
# Triple Shot                                                  25
# Triple Sunshine                                              25
# Tweak                                                        25
# Upper Case                                                   25
# V.S.O.J.                                                     25
# Very GGGreennn                                               23
# Very Green                                                   25
# Very Hazy                                                    25
# Vicinity                                                     25
# Weihenstephaner Hefeweissbier                                25
# West Ashley                                                  25
# Westly                                                       25
# Wide Awake It's Morning                                      25
# Zenne Y Frontera                                             25
# Zombie Dust                                                  25
# §ucaba                                                       25
#
# [250 rows x 2 columns]

# %%
reviews_df.columns
# Out:
# Index(['product_name', 'product_review', 'user_rating'], dtype='object')

# %%
reviews_df = reviews_df.dropna()
reviews_df['cleaned_review'] = reviews_df['product_review'].apply(lambda x :x.translate(str.maketrans('', '', string.punctuation)))
reviews_df['cleaned_review'] = reviews_df['cleaned_review'].apply(lambda x :x.lower())

reviews_df['cleaned_review'] = reviews_df['cleaned_review'].apply(word_tokenize).apply(set).apply(list)

def remove_stopwords(s):
    return [w for w in s if not w in stop_words] 
    
reviews_df['cleaned_review'] =  reviews_df['cleaned_review'].apply(remove_stopwords)

# %% [markdown]
# ### Word Frequency Analysis and Attribute Selection

# %%
#Creating a combined list of all words
all_words = []
for i in range(len(reviews_df)):
    all_words+=reviews_df['cleaned_review'][i]
from nltk import FreqDist
word_freq = nltk.FreqDist(all_words)

# %%
word_freq.most_common()
# Out:
# [('head', 3407),
#  ('beer', 2785),
#  ('taste', 2595),
#  ('pours', 1725),
#  ('nose', 1666),
#  ('sweet', 1661),
#  ('dark', 1621),
#  ('like', 1598),
#  ('one', 1596),
#  ('carbonation', 1586),
#  ('finish', 1547),
#  ('chocolate', 1536),
#  ('aroma', 1517),
#  ('nice', 1445),
#  ('mouthfeel', 1444),
#  ('good', 1430),
#  ('well', 1418),
#  ('body', 1396),
#  ('overall', 1374),
#  ('light', 1355),
#  ('lacing', 1352),
#  ('bottle', 1349),
#  ('medium', 1314),
#  ('notes', 1310),
#  ('black', 1290),
#  ('flavor', 1285),
#  ('smooth', 1235),
#  ('white', 1224),
#  ('vanilla', 1184),
#  ('bit', 1167),
#  ('color', 1166),
#  ('fruit', 1148),
#  ('bourbon', 1145),
#  ('little', 1141),
#  ('glass', 1136),
#  ('great', 1130),
#  ('orange', 1119),
#  ('flavors', 1097),
#  ('really', 1097),
#  ('thick', 1096),
#  ('feel', 1093),
#  ('poured', 1077),
#  ('smell', 1069),
#  ('coffee', 1043),
#  ('citrus', 1007),
#  ('bitterness', 944),
#  ('barrel', 932),
#  ('oak', 903),
#  ('brown', 892),
#  ('creamy', 874),
#  ('much', 870),
#  ('sweetness', 856),
#  ('hazy', 825),
#  ('malt', 818),
#  ('dry', 788),
#  ('full', 752),
#  ('big', 734),
#  ('balanced', 734),
#  ('stout', 717),
#  ('best', 715),
#  ('alcohol', 696),
#  ('still', 696),
#  ('caramel', 692),
#  ('bitter', 685),
#  ('’', 673),
#  ('get', 673),
#  ('thin', 672),
#  ('rich', 666),
#  ('pour', 644),
#  ('slightly', 641),
#  ('hops', 634),
#  ('almost', 631),
#  ('grapefruit', 629),
#  ('tropical', 616),
#  ('smells', 609),
#  ('would', 604),
#  ('quite', 600),
#  ('finger', 600),
#  ('bodied', 590),
#  ('hint', 573),
#  ('ive', 572),
#  ('abv', 565),
#  ('sour', 559),
#  ('palate', 556),
#  ('also', 555),
#  ('tart', 553),
#  ('hop', 549),
#  ('ipa', 549),
#  ('retention', 545),
#  ('mango', 545),
#  ('pineapple', 538),
#  ('complex', 537),
#  ('slight', 533),
#  ('drink', 529),
#  ('beers', 521),
#  ('funk', 520),
#  ('balance', 519),
#  ('soft', 519),
#  ('first', 518),
#  ('mouth', 507),
#  ('even', 503),
#  ('way', 500),
#  ('time', 495),
#  ('touch', 494),
#  ('lots', 489),
#  ('fresh', 488),
#  ('juicy', 485),
#  ('tan', 484),
#  ('excellent', 482),
#  ('strong', 481),
#  ('aromas', 477),
#  ('golden', 477),
#  ('amazing', 474),
#  ('better', 472),
#  ('quickly', 472),
#  ('deep', 468),
#  ('appearance', 468),
#  ('super', 466),
#  ('pine', 463),
#  ('back', 456),
#  ('definitely', 455),
#  ('perfect', 454),
#  ('front', 449),
#  ('moderate', 446),
#  ('delicious', 444),
#  ('pretty', 437),
#  ('roasted', 435),
#  ('mild', 434),
#  ('look', 431),
#  ('lemon', 428),
#  ('fruity', 427),
#  ('wine', 426),
#  ('fruits', 424),
#  ('yellow', 420),
#  ('try', 419),
#  ('style', 417),
#  ('end', 413),
#  ('malts', 411),
#  ('maple', 410),
#  ('around', 410),
#  ('juice', 409),
#  ('tastes', 404),
#  ('lot', 403),
#  ('heavy', 403),
#  ('small', 398),
#  ('sugar', 398),
#  ('ever', 397),
#  ('huge', 393),
#  ('think', 388),
#  ('top', 388),
#  ('sticky', 388),
#  ('follows', 386),
#  ('opaque', 383),
#  ('im', 379),
#  ('peach', 378),
#  ('foam', 377),
#  ('could', 376),
#  ('bright', 371),
#  ('boozy', 370),
#  ('f', 368),
#  ('vintage', 367),
#  ('earthy', 365),
#  ('l', 365),
#  ('amount', 363),
#  ('two', 358),
#  ('easy', 354),
#  ('booze', 351),
#  ('cinnamon', 350),
#  ('ring', 347),
#  ('snifter', 347),
#  ('dank', 347),
#  ('long', 346),
#  ('high', 346),
#  ('right', 345),
#  ('though', 344),
#  ('love', 342),
#  ('low', 342),
#  ('character', 341),
#  ('molasses', 339),
#  ('brew', 338),
#  ('heat', 331),
#  ('cocoa', 329),
#  ('beautiful', 323),
#  ('toffee', 322),
#  ('maybe', 321),
#  ('drinking', 321),
#  ('coconut', 319),
#  ('side', 318),
#  ('expected', 317),
#  ('subtle', 317),
#  ('oz', 317),
#  ('fantastic', 316),
#  ('comes', 314),
#  ('drinkable', 311),
#  ('lingering', 308),
#  ('worth', 306),
#  ('tongue', 304),
#  ('tulip', 304),
#  ('solid', 304),
#  ('red', 303),
#  ('base', 303),
#  ('leaves', 302),
#  ('along', 301),
#  ('another', 299),
#  ('enough', 296),
#  ('hints', 296),
#  ('aged', 295),
#  ('sip', 293),
#  ('fairly', 293),
#  ('minimal', 290),
#  ('floral', 288),
#  ('yet', 284),
#  ('complexity', 283),
#  ('milk', 282),
#  ('roast', 281),
#  ('crisp', 280),
#  ('got', 279),
#  ('2018', 278),
#  ('presence', 275),
#  ('profile', 275),
#  ('finishes', 273),
#  ('hype', 272),
#  ('without', 271),
#  ('drank', 271),
#  ('warms', 270),
#  ('brewery', 270),
#  ('stouts', 270),
#  ('aftertaste', 265),
#  ('dont', 265),
#  ('cloudy', 265),
#  ('green', 263),
#  ('cherry', 263),
#  ('tartness', 263),
#  ('favorite', 260),
#  ('sure', 259),
#  ('clean', 259),
#  ('tangerine', 259),
#  ('lace', 257),
#  ('canned', 257),
#  ('tasty', 255),
#  ('funky', 255),
#  ('say', 254),
#  ('thanks', 253),
#  ('clear', 253),
#  ('batch', 252),
#  ('less', 251),
#  ('come', 251),
#  ('syrup', 250),
#  ('present', 250),
#  ('mocha', 250),
#  ('honey', 245),
#  ('tap', 244),
#  ('looks', 244),
#  ('tons', 243),
#  ('2017', 243),
#  ('absolutely', 243),
#  ('theres', 243),
#  ('2', 241),
#  ('going', 240),
#  ('forward', 238),
#  ('nicely', 237),
#  ('enjoyable', 237),
#  ('years', 235),
#  ('date', 235),
#  ('probably', 232),
#  ('old', 232),
#  ('note', 232),
#  ('fluffy', 232),
#  ('never', 231),
#  ('awesome', 230),
#  ('gold', 230),
#  ('makes', 230),
#  ('everything', 230),
#  ('incredible', 229),
#  ('half', 229),
#  ('pale', 229),
#  ('apricot', 228),
#  ('wood', 222),
#  ('followed', 220),
#  ('hoppy', 220),
#  ('roasty', 218),
#  ('wow', 218),
#  ('doesnt', 217),
#  ('away', 215),
#  ('wonderful', 214),
#  ('12', 213),
#  ('spice', 213),
#  ('world', 212),
#  ('lightly', 211),
#  ('something', 211),
#  ('intense', 210),
#  ('many', 210),
#  ('thing', 209),
#  ('overly', 209),
#  ('perfectly', 208),
#  ('bubbles', 208),
#  ('done', 208),
#  ('similar', 208),
#  ('level', 207),
#  ('pitch', 206),
#  ('quality', 206),
#  ('colored', 206),
#  ('acidity', 206),
#  ('imperial', 206),
#  ('pleasant', 205),
#  ('foamy', 205),
#  ('2016', 203),
#  ('looking', 202),
#  ('ipas', 202),
#  ('bite', 202),
#  ('tasted', 201),
#  ('see', 201),
#  ('ba', 201),
#  ('apple', 201),
#  ('spicy', 200),
#  ('every', 200),
#  ('acidic', 200),
#  ('lingers', 199),
#  ('make', 199),
#  ('outstanding', 199),
#  ('fudge', 198),
#  ('find', 197),
#  ('tasting', 197),
#  ('together', 196),
#  ('decent', 196),
#  ('frothy', 195),
#  ('seems', 195),
#  ('enjoyed', 195),
#  ('dense', 195),
#  ('faint', 194),
#  ('leaving', 194),
#  ('new', 194),
#  ('carb', 192),
#  ('version', 191),
#  ('toasted', 190),
#  ('yeast', 190),
#  ('served', 189),
#  ('glad', 188),
#  ('ale', 188),
#  ('want', 186),
#  ('day', 186),
#  ('refreshing', 186),
#  ('amber', 186),
#  ('silky', 184),
#  ('extremely', 184),
#  ('nothing', 183),
#  ('blend', 183),
#  ('cap', 182),
#  ('fine', 181),
#  ('warming', 180),
#  ('thats', 180),
#  ('id', 180),
#  ('far', 180),
#  ('pepper', 179),
#  ('oily', 179),
#  ('chewy', 178),
#  ('tried', 178),
#  ('1', 178),
#  ('plenty', 178),
#  ('know', 177),
#  ('behind', 176),
#  ('point', 176),
#  ('hard', 175),
#  ('viscous', 174),
#  ('throughout', 174),
#  ('coming', 174),
#  ('certainly', 174),
#  ('sourness', 174),
#  ('hot', 173),
#  ('double', 173),
#  ('bottled', 173),
#  ('might', 172),
#  ('year', 172),
#  ('grape', 172),
#  ('slowly', 170),
#  ('inch', 170),
#  ('herbal', 170),
#  ('house', 170),
#  ('raspberry', 170),
#  ('experience', 169),
#  ('piney', 169),
#  ('incredibly', 168),
#  ('finally', 167),
#  ('malty', 167),
#  ('getting', 166),
#  ('cream', 165),
#  ('brings', 165),
#  ('somewhat', 165),
#  ('fades', 165),
#  ('burnt', 164),
#  ('melon', 164),
#  ('carbonated', 163),
#  ('nearly', 161),
#  ('pint', 161),
#  ('burn', 160),
#  ('cant', 160),
#  ('khaki', 160),
#  ('bomb', 160),
#  ('didnt', 159),
#  ('enjoy', 159),
#  ('made', 159),
#  ('papaya', 159),
#  ('trillium', 159),
#  ('class', 158),
#  ('cherries', 158),
#  ('regular', 158),
#  ('tree', 158),
#  ('murky', 158),
#  ('texture', 157),
#  ('different', 157),
#  ('real', 157),
#  ('last', 157),
#  ('warm', 155),
#  ('mix', 155),
#  ('isnt', 155),
#  ('3', 155),
#  ('go', 155),
#  ('dissipates', 155),
#  ('may', 154),
#  ('review', 154),
#  ('take', 154),
#  ('dipa', 154),
#  ('ripe', 154),
#  ('straw', 154),
#  ('stone', 153),
#  ('mostly', 151),
#  ('stuff', 151),
#  ('licorice', 151),
#  ('fingers', 151),
#  ('goes', 150),
#  ('highly', 149),
#  ('kind', 149),
#  ('4', 149),
#  ('actually', 149),
#  ('rind', 149),
#  ('wish', 148),
#  ('haze', 148),
#  ('sharp', 146),
#  ('raisin', 146),
#  ('16', 146),
#  ('left', 146),
#  ('middle', 145),
#  ('char', 145),
#  ('settles', 145),
#  ('raisins', 145),
#  ('adds', 144),
#  ('lighter', 144),
#  ('zest', 144),
#  ('oil', 142),
#  ('background', 142),
#  ('grassy', 142),
#  ('perhaps', 141),
#  ('hidden', 141),
#  ('syrupy', 140),
#  ('tobacco', 140),
#  ('resin', 140),
#  ('slick', 139),
#  ('release', 138),
#  ('damn', 137),
#  ('bold', 137),
#  ('liquid', 137),
#  ('velvety', 136),
#  ('surprisingly', 136),
#  ('whiskey', 133),
#  ('things', 133),
#  ('however', 133),
#  ('ton', 133),
#  ('near', 132),
#  ('gets', 132),
#  ('ago', 132),
#  ('depth', 131),
#  ('peel', 131),
#  ('unique', 131),
#  ('grass', 131),
#  ('offwhite', 130),
#  ('hill', 130),
#  ('rather', 129),
#  ('feels', 129),
#  ('although', 129),
#  ('days', 128),
#  ('flavorful', 128),
#  ('bad', 127),
#  ('oaky', 127),
#  ('cloying', 127),
#  ('candy', 127),
#  ('large', 127),
#  ('especially', 126),
#  ('classic', 126),
#  ('noticeable', 126),
#  ('draft', 126),
#  ('10', 126),
#  ('hit', 125),
#  ('fizzy', 124),
#  ('barrels', 124),
#  ('interesting', 124),
#  ('dried', 123),
#  ('said', 122),
#  ('else', 122),
#  ('jet', 122),
#  ('2019', 122),
#  ('5', 121),
#  ('teku', 121),
#  ('pink', 121),
#  ('hay', 121),
#  ('charred', 120),
#  ('750ml', 120),
#  ('found', 119),
#  ('2015', 119),
#  ('ml', 119),
#  ('easily', 118),
#  ('espresso', 118),
#  ('truly', 118),
#  ('edge', 118),
#  ('moderately', 118),
#  ('citrusy', 118),
#  ('age', 117),
#  ('leather', 117),
#  ('barnyard', 117),
#  ('loads', 116),
#  ('always', 116),
#  ('backbone', 116),
#  ('prefer', 116),
#  ('drinks', 116),
#  ('edges', 115),
#  ('let', 115),
#  ('woody', 115),
#  ('give', 115),
#  ('wild', 115),
#  ('treat', 114),
#  ('wet', 114),
#  ('price', 114),
#  ('warmth', 114),
#  ('must', 114),
#  ('straight', 114),
#  ('expect', 114),
#  ('starts', 114),
#  ('delicate', 114),
#  ('least', 113),
#  ('plus', 113),
#  ('lovely', 113),
#  ('hue', 113),
#  ('offering', 113),
#  ('bubbly', 113),
#  ('ruby', 112),
#  ('anything', 112),
#  ('16oz', 112),
#  ('collar', 112),
#  ('typical', 112),
#  ('wheat', 111),
#  ('12oz', 111),
#  ('lambic', 111),
#  ('saison', 111),
#  ('since', 110),
#  ('candied', 110),
#  ('across', 109),
#  ('decadent', 109),
#  ('fan', 108),
#  ('booziness', 108),
#  ('bread', 108),
#  ('dated', 108),
#  ('thought', 107),
#  ('put', 107),
#  ('next', 107),
#  ('given', 107),
#  ('massive', 107),
#  ('completely', 107),
#  ('hits', 107),
#  ('aging', 107),
#  ('layer', 106),
#  ('whole', 105),
#  ('smoke', 105),
#  ('mellow', 105),
#  ('recedes', 105),
#  ('start', 104),
#  ('coating', 104),
#  ('despite', 104),
#  ('neipa', 104),
#  ('2014', 103),
#  ('second', 103),
#  ('reminds', 103),
#  ('close', 103),
#  ('dryness', 103),
#  ('share', 102),
#  ('room', 102),
#  ('motor', 102),
#  ('short', 102),
#  ('trying', 102),
#  ('citra', 102),
#  ('others', 101),
#  ('rating', 101),
#  ('nutty', 101),
#  ('overwhelming', 101),
#  ('plum', 101),
#  ('linger', 101),
#  ('bready', 101),
#  ('guava', 101),
#  ('mixed', 101),
#  ('farmstead', 101),
#  ('couple', 100),
#  ('three', 100),
#  ('robust', 100),
#  ('keep', 99),
#  ('part', 99),
#  ('peppery', 98),
#  ('shared', 98),
#  ('able', 98),
#  ('cellar', 98),
#  ('seem', 97),
#  ('came', 97),
#  ('ne', 97),
#  ('night', 96),
#  ('type', 96),
#  ('prominent', 95),
#  ('impressive', 95),
#  ('spotty', 95),
#  ('45', 95),
#  ('resinous', 95),
#  ('hf', 95),
#  ('cake', 94),
#  ('dessert', 94),
#  ('bottles', 93),
#  ('fair', 93),
#  ('brett', 93),
#  ('west', 92),
#  ('drinkability', 92),
#  ('upon', 91),
#  ('upfront', 91),
#  ('tiny', 91),
#  ('effervescent', 91),
#  ('vinegar', 91),
#  ('expecting', 90),
#  ('initial', 90),
#  ('cold', 90),
#  ('dankness', 90),
#  ('grapes', 90),
#  ('add', 89),
#  ('wait', 89),
#  ('months', 89),
#  ('towards', 89),
#  ('lactic', 89),
#  ('american', 88),
#  ('oh', 88),
#  ('beige', 88),
#  ('compared', 88),
#  ('making', 88),
#  ('peppers', 88),
#  ('raspberries', 88),
#  ('overpowering', 87),
#  ('special', 87),
#  ('trade', 87),
#  ('lime', 87),
#  ('pith', 87),
#  ('round', 86),
#  ('ill', 86),
#  ('exceptional', 86),
#  ('marshmallow', 86),
#  ('average', 86),
#  ('due', 86),
#  ('peaches', 86),
#  ('bottom', 85),
#  ('grain', 85),
#  ('coats', 85),
#  ('chili', 85),
#  ('porter', 85),
#  ('bar', 84),
#  ('punch', 84),
#  ('julius', 84),
#  ('surface', 83),
#  ('swallow', 83),
#  ('higher', 83),
#  ('wasnt', 83),
#  ('example', 83),
#  ('pungent', 82),
#  ('sipper', 82),
#  ('either', 81),
#  ('legs', 81),
#  ('honestly', 81),
#  ('reviewed', 81),
#  ('added', 81),
#  ('takes', 81),
#  ('”', 81),
#  ('line', 81),
#  ('vinous', 81),
#  ('immediately', 80),
#  ('happy', 80),
#  ('8', 80),
#  ('“', 80),
#  ('pick', 80),
#  ('project', 80),
#  ('mosaic', 80),
#  ('times', 79),
#  ('earth', 79),
#  ('sweeter', 79),
#  ('buy', 79),
#  ('standard', 79),
#  ('thinner', 79),
#  ('pure', 78),
#  ('pop', 78),
#  ('brandy', 78),
#  ('gives', 78),
#  ('believe', 78),
#  ('mildly', 78),
#  ('crazy', 77),
#  ('2013', 77),
#  ('semidry', 77),
#  ('rum', 77),
#  ('spices', 77),
#  ('opened', 76),
#  ('mind', 76),
#  ('simply', 76),
#  ('guess', 76),
#  ('leave', 76),
#  ('film', 76),
#  ('soapy', 76),
#  ('barleywine', 76),
#  ('warmed', 75),
#  ('phenomenal', 75),
#  ('king', 75),
#  ('fruitiness', 75),
#  ('coast', 75),
#  ('berries', 75),
#  ('lactose', 75),
#  ('lasting', 74),
#  ('expectations', 74),
#  ('brownie', 74),
#  ('chance', 74),
#  ('used', 74),
#  ('sort', 74),
#  ('work', 74),
#  ('aggressive', 74),
#  ('need', 74),
#  ('goodness', 73),
#  ('musty', 73),
#  ('original', 73),
#  ('purchased', 73),
#  ('cut', 73),
#  ('exactly', 73),
#  ('sours', 73),
#  ('figs', 72),
#  ('layers', 72),
#  ('integrated', 72),
#  ('hands', 72),
#  ('gentle', 72),
#  ('muted', 72),
#  ('cans', 72),
#  ('home', 72),
#  ('th', 72),
#  ('earthiness', 72),
#  ('bomber', 72),
#  ('scent', 71),
#  ('residual', 71),
#  ('show', 71),
#  ('people', 71),
#  ('425', 71),
#  ('prickly', 71),
#  ('beautifully', 71),
#  ('belgian', 71),
#  ('picked', 71),
#  ('held', 71),
#  ('galaxy', 71),
#  ('friends', 70),
#  ('sugary', 70),
#  ('consumed', 70),
#  ('true', 70),
#  ('passion', 70),
#  ('open', 70),
#  ('offerings', 70),
#  ('bittersweet', 70),
#  ('blueberry', 70),
#  ('berry', 70),
#  ('fruited', 70),
#  ('thicker', 69),
#  ('pillowy', 69),
#  ('oranges', 69),
#  ('purple', 69),
#  ('acid', 69),
#  ('cantillon', 69),
#  ('750', 68),
#  ('opens', 68),
#  ('bring', 68),
#  ('works', 68),
#  ('felt', 68),
#  ('dominate', 68),
#  ('barely', 68),
#  ('tones', 68),
#  ('opinion', 67),
#  ('loved', 67),
#  ('skin', 67),
#  ('elements', 67),
#  ('apricots', 67),
#  ('blanket', 66),
#  ('reduces', 66),
#  ('amazingly', 66),
#  ('harsh', 66),
#  ('lively', 66),
#  ('spot', 66),
#  ('effervescence', 66),
#  ('flavour', 66),
#  ('6', 66),
#  ('follow', 65),
#  ('disappointed', 65),
#  ('superb', 65),
#  ('sticks', 65),
#  ('adjuncts', 65),
#  ('wouldnt', 65),
#  ('live', 65),
#  ('available', 65),
#  ('strawberry', 65),
#  ('keeps', 65),
#  ('aspect', 65),
#  ('wanted', 64),
#  ('finishing', 64),
#  ('lives', 64),
#  ('cola', 64),
#  ('somehow', 64),
#  ('list', 64),
#  ('powder', 64),
#  ('liked', 64),
#  ('already', 64),
#  ('lower', 64),
#  ('passionfruit', 64),
#  ('tangy', 64),
#  ('surprised', 64),
#  ('kick', 64),
#  ('becomes', 63),
#  ('15', 63),
#  ('tad', 63),
#  ('seek', 63),
#  ('luscious', 62),
#  ('subdued', 62),
#  ('several', 62),
#  ('blended', 62),
#  ('quick', 62),
#  ('course', 62),
#  ('soon', 62),
#  ('hides', 62),
#  ('mediumlight', 62),
#  ('brewed', 62),
#  ('toasty', 62),
#  ('nuts', 62),
#  ('pouring', 61),
#  ('breakfast', 61),
#  ('imagine', 61),
#  ('bean', 61),
#  ('sharing', 61),
#  ('otherwise', 61),
#  ('rest', 61),
#  ('friend', 61),
#  ('stronger', 61),
#  ('worthy', 61),
#  ('weeks', 61),
#  ('fridge', 61),
#  ('beans', 60),
#  ('rounded', 60),
#  ('took', 60),
#  ('rye', 60),
#  ('milky', 60),
#  ('darker', 60),
#  ('pithy', 60),
#  ('yeasty', 60),
#  ('tall', 60),
#  ('addition', 60),
#  ('wonderfully', 60),
#  ('flat', 60),
#  ('label', 60),
#  ('zero', 59),
#  ('fast', 59),
#  ('impression', 59),
#  ('case', 59),
#  ('pear', 59),
#  ('week', 59),
#  ('modest', 59),
#  ('bakers', 59),
#  ('topped', 59),
#  ('england', 59),
#  ('growler', 59),
#  ('man', 58),
#  ('remember', 58),
#  ('lucky', 58),
#  ('stands', 58),
#  ('seemed', 58),
#  ('reason', 58),
#  ('serving', 58),
#  ('feeling', 58),
#  ('bought', 58),
#  ('stemmed', 58),
#  ('jam', 58),
#  ('drying', 58),
#  ('cracker', 58),
#  ('heady', 57),
#  ('undertones', 57),
#  ('form', 57),
#  ('four', 57),
#  ('tell', 57),
#  ('use', 57),
#  ('powerful', 57),
#  ('impressed', 57),
#  ('summer', 57),
#  ('tannins', 57),
#  ('grains', 57),
#  ('gueuze', 57),
#  ('smelled', 56),
#  ('considering', 56),
#  ('smelling', 56),
#  ('creaminess', 56),
#  ('combination', 56),
#  ('turns', 56),
#  ('dominant', 56),
#  ('among', 56),
#  ('pronounced', 56),
#  ('shows', 56),
#  ('dates', 56),
#  ('taster', 56),
#  ('usual', 56),
#  ('inviting', 56),
#  ('14', 56),
#  ('qualities', 55),
#  ('recommend', 55),
#  ('hope', 55),
#  ('copper', 55),
#  ('crown', 55),
#  ('dissipated', 55),
#  ('hues', 55),
#  ('cheese', 55),
#  ('fig', 55),
#  ('plums', 54),
#  ('life', 54),
#  ('smoky', 54),
#  ('thickness', 54),
#  ('adding', 54),
#  ('place', 54),
#  ('name', 54),
#  ('single', 54),
#  ('barrelaged', 54),
#  ('characteristics', 54),
#  ('sipping', 54),
#  ('biscuit', 54),
#  ('face', 54),
#  ('seen', 54),
#  ('brewing', 54),
#  ('cheers', 54),
#  ('reddish', 54),
#  ('de', 54),
#  ('stand', 53),
#  ('simple', 53),
#  ('potent', 53),
#  ('become', 53),
#  ('apples', 53),
#  ('past', 53),
#  ('finished', 53),
#  ('batter', 53),
#  ('grainy', 53),
#  ('center', 53),
#  ('375', 53),
#  ('treehouse', 53),
#  ('fuzzy', 53),
#  ('remains', 53),
#  ('gorgeous', 53),
#  ('heard', 52),
#  ('temperature', 52),
#  ('notch', 52),
#  ('dominated', 52),
#  ('whiff', 52),
#  ('instead', 52),
#  ('nectarine', 52),
#  ('sitting', 52),
#  ('lemony', 52),
#  ('surprising', 51),
#  ('later', 51),
#  ('covered', 51),
#  ('sips', 51),
#  ('visible', 51),
#  ('relatively', 51),
#  ('colour', 51),
#  ('burst', 51),
#  ('dangerously', 51),
#  ('water', 51),
#  ('mahogany', 51),
#  ('hopped', 51),
#  ('late', 50),
#  ('likely', 50),
#  ('sense', 50),
#  ('475', 50),
#  ('particularly', 50),
#  ('entire', 50),
#  ('crafted', 50),
#  ('aromatic', 50),
#  ('kiwi', 50),
#  ('underlying', 50),
#  ('highlights', 50),
#  ('reminiscent', 50),
#  ('anise', 50),
#  ('guys', 50),
#  ('cacao', 49),
#  ('nuanced', 49),
#  ('dominates', 49),
#  ('opening', 49),
#  ('variant', 49),
#  ('initially', 49),
#  ('pack', 49),
#  ...]

# %% [markdown]
# Selected attributes:
# 1. **Crisp** - Highly carbonated; effervescent
# 2. **Hoppy** - Herbal, earthy, spicy, or citric aromas and flavors of hops
# 3. **Robust** - Rich and full-bodied

# %% [markdown]
# ### Similarity analysis with the 3-attribute set and the reviews.

# %%
import spacy
import en_core_web_lg
nlp = en_core_web_lg.load()

# %%
def join_words(comment):   
    """Joins the tokenized words to a sentence"""
    return " ".join(comment) 

reviews_df['joined_review'] = reviews_df['cleaned_review'].map(join_words)

# %%
#Calculate similarity with pre-processing functions
def calculate_similarity(comment):
    """Compute similarity score"""
    base = nlp(comment)
    compare = nlp(input_attributes)
    return base.similarity(compare)

# %%
input_list = ['crisp', 'hoppy', 'robust']
input_attributes =  " ".join(input_list)
reviews_df['similarity'] = reviews_df['joined_review'].map(calculate_similarity)

# %%
reviews_df.head(10)
# Out:
#                   product_name  \
# 0  Kentucky Brunch Brand Stout
# 1  Kentucky Brunch Brand Stout
# 2  Kentucky Brunch Brand Stout
# 3  Kentucky Brunch Brand Stout
# 4  Kentucky Brunch Brand Stout
# 5  Kentucky Brunch Brand Stout
# 6  Kentucky Brunch Brand Stout
# 7  Kentucky Brunch Brand Stout
# 8  Kentucky Brunch Brand Stout
# 9  Kentucky Brunch Brand Stout
#
#                                       product_review  user_rating  \
# 0  2016 Silver Wax. Aroma has whiskey, maple, tof...         4.80
# 1  The beer pours Pitch Black with a frothy tan h...         4.74
# 2  Probably the smoothest beer I have ever had. S...         4.68
# 3  Dark black, very thick, a little bit of tan he...         5.00
# 4  Poured black as ink with thin ruby edges at 58...         4.97
# 5  she’s got heat....but man is she somethin nice...         4.75
# 6  Amazing brew. The maple aroma pours out of thi...         5.00
# 7  Finally got to try the white whale. Pours like...         4.30
# 8  Had this on tap at the 12-15-18 release in Dec...         4.85
# 9  Had this on tap At the KBBS release 12/15/18 p...         4.89
#
#                                       cleaned_review  \
# 0  [barrel, taste, umami, cacao, aroma, toffee, w...
# 1  [creams, vanilla, frothy, pours, bottle, tan, ...
# 2  [ever, alcohol, vanilla, taste, barrel, notes,...
# 3  [ever, alcohol, either, blow, vanilla, sweet, ...
# 4  [astringency, fizzy, strong, velvety, whole, b...
# 5  [somethin, barrel, nose, booze, flavor, maple,...
# 6  [brew, pours, bottle, aroma, brownish, af, bla...
# 7  [breweries, pepper, like, think, pours, tg, gr...
# 8  [barrel, release, high, maybe, 121518, good, m...
# 9  [great, barrel, taste, release, silky, 121518,...
#
#                                        joined_review  similarity
# 0  barrel taste umami cacao aroma toffee wood map...    0.635786
# 1  creams vanilla frothy pours bottle tan feel bl...    0.602877
# 2  ever alcohol vanilla taste barrel notes probab...    0.592445
# 3  ever alcohol either blow vanilla sweet taste l...    0.536490
# 4  astringency fizzy strong velvety whole booze 5...    0.638830
# 5  somethin barrel nose booze flavor maple molass...    0.584269
# 6  brew pours bottle aroma brownish af black carb...    0.626235
# 7  breweries pepper like think pours tg green sme...    0.481698
# 8  barrel release high maybe 121518 good mix arom...    0.589091
# 9  great barrel taste release silky 121518 attemp...    0.630627

# %%
top300_reviews = reviews_df.sort_values(by='similarity', ascending=False)[0:300]

# %%
top300_reviews
# Out:
#                                            product_name  \
# 2487                               Notorious Triple IPA
# 2290                                         Flora Plum
# 4107                                     Saison Bernice
# 5609                                           Vicinity
# 4330                                            Bad Boy
# 1691                                       Doppelganger
# 5784                                            Axe Man
# 1044                                           King Sue
# 1717                                            Ephraim
# 1557                              Society & Solitude #4
# 4524                                   Fuzzy Baby Ducks
# 4422                                            Crusher
# 3654                       Mosaic Dry Hopped Fort Point
# 1225                                       Focal Banger
# 2065              Galaxy Dry Hopped Fort Point Pale Ale
# 1118                                      Double Galaxy
# 4096                                        Hopslam Ale
# 5360                              Hop JuJu Imperial IPA
# 5154             Double Dry Hopped All Citra Everything
# 3013                                         Pseudo Sue
# 1784              Double Dry Hopped Fort Point Pale Ale
# 4416                                            Crusher
# 1116                                      Double Galaxy
# 5010  Somewhere, Something Incredible Is Waiting To ...
# 5411                                Fort Point Pale Ale
# 4622                                              Bodhi
# 4931                               Ghost In The Machine
# 4306                                Double Barrel Jesus
# 3362                                  Permanent Funeral
# 4120                                     Saison Bernice
# ...                                                 ...
# 5097                      Casey / Side Project - Leaner
# 5401                                Fort Point Pale Ale
# 3291                                    Mocha Wednesday
# 1707                                       Doppelganger
# 6115                                          Scaled Up
# 1889                                         Keene Idea
# 4824                                       Black & Wild
# 5769                                            Axe Man
# 1531                                               Haze
# 939                                              Westly
# 2483                               Notorious Triple IPA
# 1918                                           Anabasis
# 3373                                  Permanent Funeral
# 1261                  Double Dry Hopped Congress Street
# 1965                                        Triple Shot
# 6035                             Double Orange Starfish
# 844                                         Zombie Dust
# 1184                                              Citra
# 6113                                          Scaled Up
# 5423                         Bourbon Barrel Black Maple
# 2097                                   The Broken Truck
# 1077                                           Headroom
# 4123                                     Saison Bernice
# 1262                  Double Dry Hopped Congress Street
# 2156                                          Alter Ego
# 5510    Imperial Eclipse Stout - Elijah Craig (12 Year)
# 1877                                         Keene Idea
# 6001                                         Mastermind
# 841                                         Zombie Dust
# 2444                               Beyond Good And Evil
#
#                                          product_review  user_rating  \
# 2487  Had on tap. Just a luscious and delicious dipa...         4.49
# 2290  2018 release.  A: Pours a very light pale, haz...         4.44
# 4107  Tasted from bottle. Classic farmhouse saison. ...         4.44
# 5609  Pours a golden peach with a fluffy fast dissip...         4.31
# 4330  Shared from a growler with Ryan. Pours a prett...         4.25
# 1691  Dark, murky orange in color with an unfiltered...         4.43
# 5784  16oz can dated 9/6/19.  Pours clear gold with ...         4.25
# 1044  16 oz can. Packaged 8/28/19, best by 12/26/19....         3.03
# 1717  Bright, refereshing, peppery, orange citrus, p...         4.60
# 1557  06/2014 - Massive pine, some tropical fruit, g...         4.44
# 4524  Cloudy amber appearance with nice head that de...         4.44
# 4422  A-Pours a hazy golden color with a nice head a...         4.65
# 3654  Nice cloudy straw/amber color with white head....         4.52
# 1225  Pours bright peach gold with a bit of haze. Th...         4.67
# 2065  11/2014 - Wow, this is amazing; incredible aro...         4.58
# 1118  Can. Full-on hazy peach color with frothy off-...         4.60
# 4096  Pours a very hazy amber color with a thick foa...         4.25
# 5360  on draft, served in a 10 oz wide topped glass ...         3.99
# 5154  On tap at Brewskival 2018.  Pours a hazy brigh...         4.49
# 3013  Murky creamsicle orange in color. Poured with ...         4.40
# 1784  A - Pours a turbid orange with a one finger fi...         4.52
# 4416  Tarnished orange in color with a murky, hazy a...         4.26
# 1116  On tap at Dive 106, NYC. Pours a hazy orange c...         4.51
# 5010  beautiful looking beer.   aromas are a mellow ...         4.57
# 5411  Canned on 12/20/17, 14:31.  Pours a really nic...         4.39
# 4622  A-Pours a very nice light amber color with a g...         4.40
# 4931  Very nice crisp hoppy IPA but a little disappo...         3.93
# 4306  Black color with a ring of brown foam. Aroma h...         4.45
# 3362  5 ounce pour at 3 Floyds in Munster. Nice dark...         4.34
# 4120  A: Moderate fruitiness, with a smooth citrus, ...         4.59
# ...                                                 ...          ...
# 5097  01/2016 - incredible peach aromas, plus white ...         4.42
# 5401  A-Hazy pineapple juice look with a nice head t...         5.00
# 3291  750 ml bottle into snifter, bottled on 1/27/20...         4.20
# 1707  16oz can. Pours a hazy burnt orange color with...         4.06
# 6115  Bright, tropical gold appearance with a creamy...         4.24
# 1889  On tap at Alpine:  A: Hazy light orange with a...         4.49
# 4824  A- Pours a murky dark brown/reddish color with...         4.76
# 5769  Pint can, served in a Duvel tulip. Canned on 0...         4.25
# 1531  This is my all-time favorite beer. It is stron...         5.00
# 939   Pours a orangish yellowish hazy color. Mild he...         4.78
# 2483  10oz draft pour at the Three Floyds Taproom, p...         4.24
# 1918  Pours murky brown. Nose is figs, raisins, toff...         4.66
# 3373  Poured a hazy dark orange with a dense looking...         4.44
# 1261  Very hazy pale color with off-white head. Arom...         4.50
# 1965  Pours black with two and a half fingers of den...         4.72
# 6035  loads of candied orange, peach rings, rich dou...         4.52
# 844   This pale ale pours a dark, burnt amber color ...         4.60
# 1184  Had on tap at KRBC. Unremarkable head at begin...         4.42
# 6113  Appearance - Pours opaque orange with thick so...         4.69
# 5423  2018 vintage - Pours dark brown-black with a k...         4.77
# 2097  B3. Massive oak, funk, tart, acidic, rustic la...         4.94
# 1077  On tap at The Veil Summer Fest.  Nice orange g...         4.50
# 4123  Poured from the bottle into a tulip. A very en...         4.28
# 1262  08/2014 - Grapefruit, floral bouquet, hops up ...         4.60
# 2156  A very good NEIPA. I get a strong amount of ci...         4.69
# 5510  Poured from the bottle into a taster. Bourbon,...         4.43
# 1877  32oz ABC growler, served in a snifter glass 9/...         4.49
# 6001  Hazy really pale yellow color with white head....         4.00
# 841   12oz bottle. 4/30/19 bottle date. Appearance: ...         4.08
# 2444  Fantastic beer. Dark brown to black appearance...         5.00
#
#                                          cleaned_review  \
# 2487  [hops, citrus, delicious, bready, backbone, 12...
# 2290  [earthy, release, spice, sourness, delicious, ...
# 4107  [earthy, mouthfeel, citrus, pours, bottle, cri...
# 5609  [hops, crackery, fruits, backbone, pours, soft...
# 4330  [hops, easy, tongue, citrus, pretty, backbone,...
# 1691  [great, murky, sweet, warmth, easy, citrus, si...
# 5784  [16oz, balancing, finishes, mouthfeel, clear, ...
# 1044  [hops, reserved, sweet, mouthfeel, 122619, pou...
# 1717  [great, refereshing, citrus, big, piney, brigh...
# 1557  [sharp, 062014, massive, flavorful, hoppiness,...
# 4524  [taste, citrus, aroma, appearance, hint, cloud...
# 4422  [taste, citrus, nose, color, lacing, flavor, b...
# 3654  [combination, hops, taste, pleasant, citrus, c...
# 1225  [toasty, hops, taste, mouthfeel, apricot, high...
# 2065  [wow, mildly, hops, sweet, zesty, good, peach,...
# 1118  [hops, also, taste, 8, fruits, frothy, notes, ...
# 4096  [honey, taste, slight, astringent, citrus, nos...
# 5360  [served, taste, mouthfeel, pleasant, clear, ci...
# 5154  [dankness, sweet, taste, mouthfeel, citrus, no...
# 3013  [gets, silky, bodied, expands, slowly, middle,...
# 1784  [hops, another, taste, mouthfeel, fizzy, apric...
# 4416  [earthy, murky, warmth, high, pleasant, solid,...
# 1116  [redolent, saturn, dominant, pours, neat, arom...
# 5010  [earthy, complexity, vanilla, still, mouthfeel...
# 5411  [least, warms, small, great, ale, 122017, grap...
# 4622  [oa, resonating, taste, nose, color, lacing, f...
# 4931  [impress, hops, vanilla, taste, mouthfeel, lit...
# 4306  [taste, fruits, umami, color, soft, chocolatey...
# 3362  [colour, sweet, taste, mouthfeel, little, plea...
# 4120  [example, nearly, absolutely, slight, flawless...
# ...                                                 ...
# 5097  [012016, sweet, peachy, plus, spritzy, hell, a...
# 5401  [great, sweet, also, slight, little, harsh, fl...
# 3291  [warms, great, almond, still, khaki, huge, pou...
# 1707  [16oz, alcohol, hops, papaya, warmth, still, a...
# 6115  [honey, firm, great, notes, ghosting, backgrou...
# 1889  [gentle, small, hops, crackery, sweet, persist...
# 4824  [example, slight, collar, pours, aroma, recede...
# 5769  [mixed, persistent, pint, strong, strands, can...
# 1531  [alltime, aspects, haze, nose, strong, —, fine...
# 939   [ever, alcohol, incredibly, taste, high, one, ...
# 2483  [great, pours, strong, booze, aroma, offers, b...
# 1918  [example, murky, taste, mouthfeel, bit, nose, ...
# 3373  [alcohol, hops, great, feels, sweet, taste, li...
# 1261  [taste, really, harsh, color, aroma, hazy, car...
# 1965  [beautifully, pours, aroma, sublime, top, midd...
# 6035  [honey, provides, mouthfeel, notes, herbaceous...
# 844   [slight, pours, green, could, caramel, dry, ro...
# 1184  [stunning, honey, easy, 8, citrus, built, colo...
# 6113  [alcohol, powerful, great, sweet, taste, littl...
# 5423  [earthy, hops, crackery, vanilla, barrel, crac...
# 2097  [oak, tart, long, rustic, oaky, funk, lacing, ...
# 1077  [fest, papaya, veil, taste, mouthfeel, earthin...
# 4123  [mouthfeel, bottle, good, enjoyable, brett, ca...
# 1262  [hops, bit, pepper, front, 082014, bouquet, ho...
# 2156  [hops, brew, citrus, like, background, strong,...
# 5510  [mouthfeel, oak, solid, bottle, bodied, roaste...
# 1877  [slight, pours, bodied, bold, heat, barleywine...
# 6001  [earthy, alcohol, taste, really, bit, notes, c...
# 841   [stronger, strong, aroma, bodied, decent, clou...
# 2444  [dessert, sweet, mouthfeel, certainly, soft, b...
#
#                                           joined_review  similarity
# 2487  hops citrus delicious bready backbone 12 hazy ...    0.797940
# 2290  earthy release spice sourness delicious minima...    0.795650
# 4107  earthy mouthfeel citrus pours bottle crisp fun...    0.794142
# 5609  hops crackery fruits backbone pours soft crisp...    0.792530
# 4330  hops easy tongue citrus pretty backbone pours ...    0.792521
# 1691  great murky sweet warmth easy citrus silky not...    0.790991
# 5784  16oz balancing finishes mouthfeel clear haze c...    0.790588
# 1044  hops reserved sweet mouthfeel 122619 pours 828...    0.790280
# 1717  great refereshing citrus big piney bright 10 w...    0.789249
# 1557  sharp 062014 massive flavorful hoppiness bitte...    0.788851
# 4524  taste citrus aroma appearance hint cloudy head...    0.786717
# 4422  taste citrus nose color lacing flavor bodied h...    0.785952
# 3654  combination hops taste pleasant citrus color a...    0.785757
# 1225  toasty hops taste mouthfeel apricot high bit h...    0.785229
# 2065  wow mildly hops sweet zesty good peach poppin ...    0.784344
# 1118  hops also taste 8 fruits frothy notes like col...    0.784202
# 4096  honey taste slight astringent citrus nose pour...    0.784003
# 5360  served taste mouthfeel pleasant clear citrus w...    0.783334
# 5154  dankness sweet taste mouthfeel citrus notes te...    0.778096
# 3013  gets silky bodied expands slowly middle charac...    0.777092
# 1784  hops another taste mouthfeel fizzy apricot one...    0.776799
# 4416  earthy murky warmth high pleasant solid notes ...    0.776069
# 1116  redolent saturn dominant pours neat aroma bodi...    0.775867
# 5010  earthy complexity vanilla still mouthfeel litt...    0.775577
# 5411  least warms small great ale 122017 grapefruity...    0.774793
# 4622  oa resonating taste nose color lacing flavor b...    0.774729
# 4931  impress hops vanilla taste mouthfeel little hi...    0.774711
# 4306  taste fruits umami color soft chocolatey spect...    0.773303
# 3362  colour sweet taste mouthfeel little pleasant c...    0.773225
# 4120  example nearly absolutely slight flawless frui...    0.772989
# ...                                                 ...         ...
# 5097  012016 sweet peachy plus spritzy hell acidic s...    0.732502
# 5401  great sweet also slight little harsh flavour j...    0.732436
# 3291  warms great almond still khaki huge pours brue...    0.732166
# 1707  16oz alcohol hops papaya warmth still also tas...    0.732107
# 6115  honey firm great notes ghosting background dra...    0.732069
# 1889  gentle small hops crackery sweet persist notes...    0.732038
# 4824  example slight collar pours aroma recedes carb...    0.732011
# 5769  mixed persistent pint strong strands canned mi...    0.731954
# 1531  alltime aspects haze nose strong — fine feel p...    0.731940
# 939   ever alcohol incredibly taste high one tart al...    0.731910
# 2483  great pours strong booze aroma offers bodied b...    0.731898
# 1918  example murky taste mouthfeel bit nose like po...    0.731837
# 3373  alcohol hops great feels sweet taste likely sl...    0.731736
# 1261  taste really harsh color aroma hazy carbonatio...    0.731718
# 1965  beautifully pours aroma sublime top middle pro...    0.731708
# 6035  honey provides mouthfeel notes herbaceousness ...    0.731667
# 844   slight pours green could caramel dry rocky gra...    0.731665
# 1184  stunning honey easy 8 citrus built color krbc ...    0.731600
# 6113  alcohol powerful great sweet taste little tong...    0.731274
# 5423  earthy hops crackery vanilla barrel cracker sl...    0.731076
# 2097  oak tart long rustic oaky funk lacing feel aci...    0.730982
# 1077  fest papaya veil taste mouthfeel earthiness du...    0.730969
# 4123  mouthfeel bottle good enjoyable brett carbonat...    0.730909
# 1262  hops bit pepper front 082014 bouquet hopped pe...    0.730861
# 2156  hops brew citrus like background strong clemen...    0.730578
# 5510  mouthfeel oak solid bottle bodied roasted choc...    0.730560
# 1877  slight pours bodied bold heat barleywine inter...    0.730412
# 6001  earthy alcohol taste really bit notes color go...    0.730386
# 841   stronger strong aroma bodied decent cloudy car...    0.730248
# 2444  dessert sweet mouthfeel certainly soft brown w...    0.730176
#
# [300 rows x 6 columns]

# %% [markdown]
# ### Sentiment analysis on top 300 reviews and Sorting them (high to low) by the sentiment scores.

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
def sentiment_analyzer_scores(sentence):
    """Generate seniment score"""
    scores = analyser.polarity_scores(sentence)
    return scores['compound']

top300_reviews['sentiment'] = top300_reviews['product_review'].map(sentiment_analyzer_scores)

# %%
top300_reviews_sentiment = top300_reviews.sort_values(by='sentiment', ascending=False)

# %%
top300_reviews_sentiment
# Out:
#                                  product_name  \
# 3458                                 Darkness
# 1626                       Oude Geuze Vintage
# 4930                     Ghost In The Machine
# 5044                          Emerald Grouper
# 3291                          Mocha Wednesday
# 4654                                      Art
# 3512                   Montmorency Vs Balaton
# 5315                                    Flora
# 5827                                  Thicket
# 2497                     Notorious Triple IPA
# 1866                               Keene Idea
# 1824                                   Clover
# 1386                          Sip Of Sunshine
# 2483                     Notorious Triple IPA
# 5621  Jackie O's / Side Project - Appervation
# 3258                             Abrasive Ale
# 1877                               Keene Idea
# 6023                   Double Orange Starfish
# 608                                    Dinner
# 4056                                Last Snow
# 3216                               Gggreennn!
# 4824                             Black & Wild
# 6113                                Scaled Up
# 5294                                    Flora
# 1443                                    Swish
# 5145   Double Dry Hopped All Citra Everything
# 6047               Dorothy (Wine Barrel Aged)
# 5353                    Hop JuJu Imperial IPA
# 4630                   Barrel-Aged Silhouette
# 5405                      Fort Point Pale Ale
# ...                                       ...
# 4524                         Fuzzy Baby Ducks
# 3061                          Pugachev Royale
# 4558                                    Sosus
# 2918                            In Perpetuity
# 4041                            Double Nelson
# 828                               Zombie Dust
# 1108                            Double Galaxy
# 5401                      Fort Point Pale Ale
# 4509                         Fuzzy Baby Ducks
# 5609                                 Vicinity
# 1261        Double Dry Hopped Congress Street
# 1194                                    Citra
# 5611                                 Vicinity
# 1262        Double Dry Hopped Congress Street
# 5097            Casey / Side Project - Leaner
# 1462                                    Swish
# 3342                            Scaled Way Up
# 1225                             Focal Banger
# 5791                                  Axe Man
# 1291                                    Green
# 104                              Heady Topper
# 1557                    Society & Solitude #4
# 1242                             Focal Banger
# 5784                                  Axe Man
# 965                             Double Citra®
# 5391                            Second Fiddle
# 1118                            Double Galaxy
# 2923                            In Perpetuity
# 2142                                Alter Ego
# 5983                        Darkstar November
#
#                                          product_review  user_rating  \
# 3458  750 ml bottle into snifter, bottled on 9/25/20...         4.36
# 1626  750ml bottle, 2008 vintage, poured into a Drie...         4.58
# 4930  12 ounce bottle into tulip glass, bottled on 8...         4.28
# 5044  16 ounce can into tulip glass, canned on 9/24/...         4.23
# 3291  750 ml bottle into snifter, bottled on 1/27/20...         4.20
# 4654  375ml bottle, Batch 5, dated March 18, 2015, p...         4.67
# 3512  500 ml bottle into signature tulip glass; Blen...         4.37
# 5315  750ml bottle, Batch #6, poured into a Hill Far...         4.51
# 5827  375ml bottle, generously shared by Erik, poure...         4.19
# 2497  had this on tap at the mule bar in Winooski VT...         4.34
# 1866  16oz can, dated 08.05.19, poured into a 14oz s...         4.33
# 1824  375ml bottle, poured into a Hill Farmstead ove...         4.56
# 1386  Pours a mostly clear albeit cloudy orange colo...         4.26
# 2483  10oz draft pour at the Three Floyds Taproom, p...         4.24
# 5621  375 ml bottle into snifter, 2018 vintage bottl...         4.35
# 3258  Poured from a pint can into a tulip  The aroma...         4.44
# 1877  32oz ABC growler, served in a snifter glass 9/...         4.49
# 6023  Drank from a 1 pint (473ml) can purchased at A...         4.58
# 608   16oz bottle, dated 7.26.19, poured into a 14oz...         4.55
# 4056  Pours a pitch black coloration with a large, c...         4.45
# 3216  Another incredible, outstanding NE style IPA f...         4.49
# 4824  A- Pours a murky dark brown/reddish color with...         4.76
# 6113  Appearance - Pours opaque orange with thick so...         4.69
# 5294  Batch 7  beautiful looking beer, hazed golden ...         5.00
# 1443  Absolutely fantastic NE style IPA. I’m coming ...         4.43
# 5145  On tap at George Keeley, NYC. Pours a turbid y...         4.40
# 6047  B2 April 4, 2017  pours out a mostly clear bri...         5.00
# 5353  Poured into a snifter.  4.0 A: Clear light ora...         4.14
# 4630  750 ml bottle into snifter; 2018 vintage, bott...         4.25
# 5405  Pours a hazy peach coloration with a small, fi...         4.38
# ...                                                 ...          ...
# 4524  Cloudy amber appearance with nice head that de...         4.44
# 3061  Dark brown color with a ring of brownish foam....         4.60
# 4558  16oz can dated 2/14/19.  Pours hazy gold with ...         4.25
# 2918  16oz can dated 3/7/19.  Pours cloudy yellow wi...         4.30
# 4041  12oz. can served in a tulip. Pours a bright, h...         4.03
# 828   12 oz bottle poured into a tulip pint.  Appear...         4.29
# 1108  Soft gold, foamy head. Aroma has underripe mel...         4.37
# 5401  A-Hazy pineapple juice look with a nice head t...         5.00
# 4509  On tap at the brewery Hazy gold, three fingers...         4.39
# 5609  Pours a golden peach with a fluffy fast dissip...         4.31
# 1261  Very hazy pale color with off-white head. Arom...         4.50
# 1194  Pours a light orange color with a soapy head. ...         4.21
# 5611  Pours Golden yellow, frothy head of foam and t...         4.33
# 1262  08/2014 - Grapefruit, floral bouquet, hops up ...         4.60
# 5097  01/2016 - incredible peach aromas, plus white ...         4.42
# 1462  Sample at Mikkeller Beer Celebration Copenhage...         4.60
# 3342  16oz can dated 2/9/18.  Pours cloudy gold with...         4.51
# 1225  Pours bright peach gold with a bit of haze. Th...         4.67
# 5791  16oz. can served in a willibecker. Pours a dul...         3.79
# 1291  Look - hazy, dark orange, not a lot of head or...         4.05
# 104   Moderately high haze, golden yellow color, wit...         4.25
# 1557  06/2014 - Massive pine, some tropical fruit, g...         4.44
# 1242  Poured from can to tulip, hazy yellow, white h...         4.43
# 5784  16oz can dated 9/6/19.  Pours clear gold with ...         4.25
# 965   Had a brewery and brought grower home, poured ...         4.51
# 5391  Almost clear golden color with off-white head....         3.75
# 1118  Can. Full-on hazy peach color with frothy off-...         4.60
# 2923  Really hazy yellow color with off-white head. ...         4.25
# 2142  16oz can dated 3/19/19.  Pours murky gold with...         4.04
# 5983  Dark brown color with tan head. Aroma is boozy...         4.40
#
#                                          cleaned_review  \
# 3458  [example, warms, old, great, huge, modestly, g...
# 1626  [great, spice, pours, aroma, special, green, j...
# 4930  [example, great, 8, huge, pours, highly, danke...
# 5044  [example, great, astringency, huge, pours, hig...
# 3291  [warms, great, almond, still, khaki, huge, pou...
# 4654  [vinous, great, beautifully, spice, march, ber...
# 3512  [example, great, tier, huge, modestly, grass, ...
# 5315  [example, great, another, berry, pours, shauns...
# 5827  [used, pours, blackberry, 375ml, aroma, offers...
# 2497  [isnt, still, bar, triple, necessarily, maybe,...
# 1866  [line, great, toeing, spice, pours, booze, aro...
# 1824  [beautifully, still, pours, 375ml, aroma, farm...
# 1386  [example, pours, strong, velvety, aroma, bronz...
# 2483  [great, pours, strong, booze, aroma, offers, b...
# 5621  [example, warms, great, tier, boozytannic, hug...
# 3258  [gets, decidedly, every, persistent, pint, ber...
# 1877  [slight, pours, bodied, bold, heat, barleywine...
# 6023  [fruitiness, release, new, pint, collar, strea...
# 608   [great, beautifully, still, maine, puree, pour...
# 4056  [earthyspicy, great, spice, pours, roasted, ca...
# 3216  [great, another, tree, pours, top, canned, loo...
# 4824  [example, slight, collar, pours, aroma, recede...
# 6113  [alcohol, powerful, great, sweet, taste, littl...
# 5294  [beautifully, vanilla, batch, charter, complim...
# 1443  [great, pours, canned, brewery, coming, grapef...
# 5145  [soon, great, spice, pours, faint, aroma, bodi...
# 6047  [great, spice, characteristics, grass, pours, ...
# 5353  [isnt, evergreen, shrubbery, rounded, sip, slo...
# 4630  [example, great, khaki, huge, grass, pours, hi...
# 5405  [still, fizzy, takes, pours, grapefruit, beer,...
# ...                                                 ...
# 4524  [taste, citrus, aroma, appearance, hint, cloud...
# 3061  [earthy, sweet, fruits, bit, notes, color, sof...
# 4558  [16oz, shades, finishes, mouthfeel, citrus, mi...
# 2918  [16oz, line, finishes, mouthfeel, citrus, bit,...
# 4041  [earthy, served, highlight, taste, mouthfeel, ...
# 828   [taste, slight, mouthfeel, ale, pint, 12, nose...
# 1108  [earthy, hops, little, apricot, pretty, like, ...
# 5401  [great, sweet, also, slight, little, harsh, fl...
# 4509  [alcohol, great, mouthfeel, apricot, strong, s...
# 5609  [hops, crackery, fruits, backbone, pours, soft...
# 1261  [taste, really, harsh, color, aroma, hazy, car...
# 1194  [taste, ale, solid, citrus, pours, color, stro...
# 5611  [warms, hops, slight, really, citrus, frothy, ...
# 1262  [hops, bit, pepper, front, 082014, bouquet, ho...
# 5097  [012016, sweet, peachy, plus, spritzy, hell, a...
# 1462  [taste, also, fruitiness, bit, mikkeller, soft...
# 3342  [16oz, throat, hops, finishes, warmth, dated, ...
# 1225  [toasty, hops, taste, mouthfeel, apricot, high...
# 5791  [16oz, served, hops, old, taste, mouthfeel, ch...
# 1291  [taste, tongue, hits, citrus, smell, lacing, p...
# 104   [lime, high, persistent, haze, bready, cotrucy...
# 1557  [sharp, 062014, massive, flavorful, hoppiness,...
# 1242  [taste, bready, notes, nose, lacing, funk, min...
# 5784  [16oz, balancing, finishes, mouthfeel, clear, ...
# 965   [alcohol, home, hops, great, stringy, slight, ...
# 5391  [hops, complexity, sweet, taste, basic, harsh,...
# 1118  [hops, also, taste, 8, fruits, frothy, notes, ...
# 2923  [taste, really, citrus, color, good, aroma, ha...
# 2142  [least, 16oz, finishes, murky, mouthfeel, citr...
# 5983  [earthy, taste, harsh, bit, color, tan, good, ...
#
#                                           joined_review  similarity  sentiment
# 3458  example warms old great huge modestly grass po...    0.735552     0.9976
# 1626  great spice pours aroma special green journal ...    0.742722     0.9972
# 4930  example great 8 huge pours highly dankearthy e...    0.744781     0.9966
# 5044  example great astringency huge pours highly 95...    0.764206     0.9961
# 3291  warms great almond still khaki huge pours brue...    0.732166     0.9959
# 4654  vinous great beautifully spice march berry pou...    0.735175     0.9951
# 3512  example great tier huge modestly grass pours h...    0.735357     0.9950
# 5315  example great another berry pours shauns oaky ...    0.745116     0.9948
# 5827  used pours blackberry 375ml aroma offers yeast...    0.742931     0.9945
# 2497  isnt still bar triple necessarily maybe pours ...    0.743096     0.9939
# 1866  line great toeing spice pours booze aroma top ...    0.734904     0.9929
# 1824  beautifully still pours 375ml aroma farmstead ...    0.735919     0.9925
# 1386  example pours strong velvety aroma bronzed bod...    0.739482     0.9921
# 2483  great pours strong booze aroma offers bodied b...    0.731898     0.9919
# 5621  example warms great tier boozytannic huge pour...    0.733881     0.9915
# 3258  gets decidedly every persistent pint berry pea...    0.756216     0.9904
# 1877  slight pours bodied bold heat barleywine inter...    0.730412     0.9904
# 6023  fruitiness release new pint collar streaky yel...    0.752127     0.9899
# 608   great beautifully still maine puree pours arom...    0.735884     0.9893
# 4056  earthyspicy great spice pours roasted caramel ...    0.732918     0.9887
# 3216  great another tree pours top canned looking br...    0.735976     0.9875
# 4824  example slight collar pours aroma recedes carb...    0.732011     0.9871
# 6113  alcohol powerful great sweet taste little tong...    0.731274     0.9868
# 5294  beautifully vanilla batch charter complimentar...    0.749228     0.9864
# 1443  great pours canned brewery coming grapefruit l...    0.743182     0.9864
# 5145  soon great spice pours faint aroma bodied focu...    0.755722     0.9860
# 6047  great spice characteristics grass pours oaky c...    0.737241     0.9848
# 5353  isnt evergreen shrubbery rounded sip slowly ca...    0.738049     0.9847
# 4630  example great khaki huge grass pours highly bo...    0.738767     0.9847
# 5405  still fizzy takes pours grapefruit beer though...    0.736601     0.9842
# ...                                                 ...         ...        ...
# 4524  taste citrus aroma appearance hint cloudy head...    0.786717     0.0258
# 3061  earthy sweet fruits bit notes color soft brown...    0.742215     0.0258
# 4558  16oz shades finishes mouthfeel citrus minimal ...    0.744395     0.0129
# 2918  16oz line finishes mouthfeel citrus bit minima...    0.736290     0.0129
# 4041  earthy served highlight taste mouthfeel citrus...    0.742193     0.0119
# 828   taste slight mouthfeel ale pint 12 nose bottle...    0.759796    -0.0000
# 1108  earthy hops little apricot pretty like maybe s...    0.745108    -0.0377
# 5401  great sweet also slight little harsh flavour j...    0.732436    -0.0671
# 4509  alcohol great mouthfeel apricot strong stubbor...    0.747449    -0.0772
# 5609  hops crackery fruits backbone pours soft crisp...    0.792530    -0.1045
# 1261  taste really harsh color aroma hazy carbonatio...    0.731718    -0.1210
# 1194  taste ale solid citrus pours color strong doub...    0.750741    -0.1280
# 5611  warms hops slight really citrus frothy backbon...    0.733005    -0.1531
# 1262  hops bit pepper front 082014 bouquet hopped pe...    0.730861    -0.1531
# 5097  012016 sweet peachy plus spritzy hell acidic s...    0.732502    -0.1672
# 1462  taste also fruitiness bit mikkeller soft color...    0.766619    -0.2263
# 3342  16oz throat hops finishes warmth dated mouthfe...    0.744934    -0.3673
# 1225  toasty hops taste mouthfeel apricot high bit h...    0.785229    -0.3720
# 5791  16oz served hops old taste mouthfeel change ci...    0.740822    -0.3818
# 1291  taste tongue hits citrus smell lacing preferen...    0.737492    -0.4019
# 104   lime high persistent haze bready cotrucy juice...    0.751668    -0.4019
# 1557  sharp 062014 massive flavorful hoppiness bitte...    0.788851    -0.4215
# 1242  taste bready notes nose lacing funk mineral ha...    0.746665    -0.4215
# 5784  16oz balancing finishes mouthfeel clear haze c...    0.790588    -0.4588
# 965   alcohol home hops great stringy slight brew ci...    0.745368    -0.4881
# 5391  hops complexity sweet taste basic harsh astrin...    0.756319    -0.5124
# 1118  hops also taste 8 fruits frothy notes like col...    0.784202    -0.5958
# 2923  taste really citrus color good aroma hazy carb...    0.738797    -0.7786
# 2142  least 16oz finishes murky mouthfeel citrus pea...    0.738741    -0.8003
# 5983  earthy taste harsh bit color tan good booze ar...    0.754585    -0.8340
#
# [300 rows x 7 columns]

# %% [markdown]
# ### Recommend 3 beers to the customer based on similarity and sentiment

# %%
top300_reviews_combined = top300_reviews.groupby('product_name')[['similarity','sentiment']].mean()
top300_reviews_combined['recommend'] = top300_reviews_combined['similarity']+top300_reviews_combined['sentiment']

# %%
top300_reviews_combined.sort_values(by='recommend', ascending=False)[0:3]
# Out:
#                  similarity  sentiment  recommend
# product_name
# Emerald Grouper    0.764206     0.9961   1.760306
# Flora              0.747172     0.9906   1.737772
# Thicket            0.742931     0.9945   1.737431

# %% [markdown]
# ### Recommend 3 beers to the customer based on similarity, sentiment and user rating

# %%
reviews_df['sentiment'] = reviews_df['product_review'].map(sentiment_analyzer_scores)

# %%
reviews_df_combined = reviews_df.groupby('product_name')[['similarity','sentiment', 'user_rating']].mean()
reviews_df_combined['recommend'] = reviews_df_combined['similarity']+reviews_df_combined['sentiment']

# %%
reviews_df_combined.sort_values(by = 'user_rating', ascending = False)[0:3]
# Out:
#                              similarity  sentiment  user_rating  recommend
# product_name
# Chemtrailmix                   0.591402   0.883917     4.816667   1.475318
# Kentucky Brunch Brand Stout    0.568817   0.787348     4.812000   1.356165
# It Was All A Dream             0.578521   0.600915     4.785000   1.179436

# %%
reviews_df_combined['recommend'].min()
# Out:
# 1.1332525622299112

# %% [markdown]
# ### Difference in the two recommendation methods
# The recommendations change quite a bit between the two methods. One major reason is because we are using the entire dataset of reviews rather than those that are most similar to the attributes we are looking for. We are looking at all reviews for all products, regardless of the review's relevance to the input attributes (we used 'crisp', 'hoppy', and 'robust'). In general for something as subjective as beer preferences, using all of the reviews is not going to recommend anything personal to the user. Just because a lot of people like it doesn't mean that everyone likes it. For example, it's a hot topic right now whether or not pineapple should be a pizza topping. There are millions of people who love pineapple on pizza and will take to the internet to explain why it's great, but that doesn't mean that I will like pineapple pizza. I might prefer my pizza to be more savory and meaty rather than sweet, and that's exactly what is going on here. Just because lots of people like IPAs and that they are highly rated doesn't mean that everyone will like them- I've spat out a highly rated IPA before because I thought it was way to bitter and intense, which is why a lot of people liked it. This isn't about functionality- it's about taste, which differs person to person. That is why recommending the top rated beers without paying attention to similarity and sentiment isn't a good idea- you can see from the output above that the three top rated beers overall do not all fit well with our input attributes. One of them is actually one of the worst recommendation scores that we have in the dataset with a score of 1.179436. The other two perform closer to the mean recommendation of the set. Ultimately, blindly recommending high-rated beers will not meet the requirements of the user looking for recommendations.
